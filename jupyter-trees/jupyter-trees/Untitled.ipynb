# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Street_Tree_List.csv')

# %%
zip_c = df['Zip Codes']
zip_c.value_counts().count()
# Out:
# 29

# %% [markdown]
# counting amount of zipcodes

# %%
df['TreeID'].count()
# Out:
# 195765

# %% [markdown]
# total trees on file

# %%
df['qSiteInfo'].unique()
# Out:
# array(['Sidewalk: Curb side : Cutout', 'Side Yard : Yard',
#        'Back Yard : Yard', 'Sidewalk: Property side : Yard',
#        'Median : Yard', 'Unaccepted Street : Yard', 'Front Yard : Yard',
#        'Sidewalk: Curb side : Yard', 'Sidewalk: Property side : Cutout',
#        'Unaccepted Street : Cutout', 'Median : Cutout',
#        'Side Yard : Cutout', 'unknown : Yard', 'Back Yard : Cutout',
#        'Sidewalk: Curb side : Pot', 'Sidewalk: Curb side :', 'Median :',
#        ':', 'Front Yard : Pot', 'Front Yard : Cutout',
#        'Unaccepted Street : Pot', ': Yard', ': Cutout', 'Front Yard :',
#        'Sidewalk: Property side : Pot', 'Sidewalk: Property side :',
#        'unknown : Cutout', 'Hanging basket : Cutout',
#        'Sidewalk: Curb side : Hanging Pot', 'Hanging basket : Yard',
#        'unknown : Pot', 'Median : Hanging Pot'], dtype=object)

# %% [markdown]
# site info options

# %%
df['qCaretaker'].value_counts()
# Out:
# Private                    164075
# DPW                         27950
# SFUSD                        1100
# Port                          726
# Rec/Park                      722
# PUC                           261
# DPW for City Agency           210
# MTA                           109
# Dept of Real Estate            94
# Purchasing Dept                85
# Housing Authority              73
# Fire Dept                      68
# Health Dept                    56
# Police Dept                    50
# Public Library                 37
# Mayor Office of Housing        37
# Arts Commission                31
# Office of Mayor                27
# War Memorial                   20
# Mission Verde                  15
# City College                   11
# Asian Arts Commission           6
# CAN                             1
# Cleary Bros. Landscape          1
# Name: qCaretaker, dtype: int64

# %% [markdown]
# private caretaker more popular than dpw

# %%
incom_col = df.columns[df.isnull().any()]
incom_col
# Out:
# Index(['qLegalStatus', 'qAddress', 'SiteOrder', 'qCareAssistant', 'PlantDate',
#        'DBH', 'PlotSize', 'PermitNotes', 'XCoord', 'YCoord', 'Latitude',
#        'Longitude', 'Location', 'Fire Prevention Districts',
#        'Police Districts', 'Supervisor Districts', 'Zip Codes',
#        'Neighborhoods (old)'],
#       dtype='object')

# %%
for column in df:
    print(column)
    print(df[column].isnull())
# Out:
# TreeID
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 195760    False
# 195761    False
# 195762    False
# 195763    False
# 195764    False
# Name: TreeID, Length: 195765, dtype: bool
# qLegalStatus
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 195760    False
# 195761    False
# 195762    False
# 195763    False
# 195764    False
# Name: qLegalStatus, Length: 195765, dtype: bool
# qSpecies
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 195760    False
# 195761    False
# 195762    False
# 195763    False
# 195764    False
# Name: qSpecies, Length: 195765, dtype: bool
# qAddress
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 195760    False
# 195761    False
# 195762    False
# 195763    False
# 195764    False
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
trees_an_zip = df.groupby('Zip Codes')['TreeID'].count()
trees_an_zip
# Out:
# Zip Codes
# 54.0        9405
# 55.0        7410
# 56.0       10470
# 57.0        5626
# 58.0       12214
# 59.0        7359
# 61.0          32
# 62.0           4
# 63.0        9175
# 64.0        4566
# 308.0       4596
# 309.0       5418
# 310.0       1607
# 28588.0        7
# 28590.0        1
# 28852.0     6248
# 28853.0     8667
# 28854.0      309
# 28855.0     2494
# 28856.0     8852
# 28857.0     1273
# 28858.0     7515
# 28859.0    21286
# 28860.0     2365
# 28861.0    12865
# 28862.0    13009
# 29490.0     9687
# 29491.0     9611
# 29492.0    10611
# Name: TreeID, dtype: int64

# %%
plt.hist(trees_an_zip)
# Out:
# (array([7., 2., 5., 3., 8., 1., 2., 0., 0., 1.]),
#  array([1.00000e+00, 2.12950e+03, 4.25800e+03, 6.38650e+03, 8.51500e+03,
#         1.06435e+04, 1.27720e+04, 1.49005e+04, 1.70290e+04, 1.91575e+04,
#         2.12860e+04]),
#  <BarContainer object of 10 artists>)

# %%
# x = df.groupby('qCaretaker')['TreeID'].count()
df.loc[df['qCaretaker'] == ('Private' and 'DPW'), : ]
# Out:
#         TreeID    qLegalStatus  \
# 1        19725  DPW Maintained
# 2       121399  DPW Maintained
# 4       251210  DPW Maintained
# 7       255131  DPW Maintained
# 8       255229  DPW Maintained
# ...        ...             ...
# 195751   21106  DPW Maintained
# 195757  140331  DPW Maintained
# 195758   20242  DPW Maintained
# 195760     231  DPW Maintained
# 195764   15238  DPW Maintained
#
#                                                  qSpecies  \
# 1                                   Pinus Spp :: Pine Spp
# 2                 Corymbia ficifolia :: Red Flowering Gum
# 4       Eucalyptus polyanthemos :: Silver Dollar Eucal...
# 7                 Corymbia ficifolia :: Red Flowering Gum
# 8                   Lophostemon confertus :: Brisbane Box
# ...                                                   ...
# 195751           Cupressus macrocarpa :: Monterey Cypress
# 195757     Platanus x hispanica :: Sycamore: London Plane
# ...
